# %% [markdown]
# <a href="https://colab.research.google.com/github/MaryamRafieipour/Initial-Algorithm/blob/master/Factors_JSON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json

factors = {
    'ALT' : {
        'name' : ['ALT', 'ALTA', 'ALANINE AMINOTRANSFERASE'],
        'multiple factors' : {'type' : True, 'other factors' : 'AST', 'relation' : 'or'},
        'reference range' : {
            'female' : [{'Name' : 'ALT', 'Lower Limit' : 19, 'Upper Limit' : 25 }],
            'male' : [{'Name' : 'ALT', 'Lower Limit' : 29, 'Upper Limit' : 33 }]
        },
        'abnormality':{
            'high' : [
                      {'Name' : 'Review',
                       'Question based' : True,
                       'Value based': False,
                       'Operation': None,
                       'Obtain' : 'REVIEW:\n\u2022 Tests that may be available at the time of diagnosis: \
                       \n  1. liver biochemical tests including total and direct bilirubin, alkaline phosphatase, gamma-glutamyl transpeptidase [GGT], albumin;\
                       \n  2. serum electrolytes, blood urea nitrogen [BUN], creatinine, glucose, and other chemistries;\
                       \n  3. complete blood count [CBC] with differential and platelet count;\
                       \n  4. international normalized ratio\
                       \n\u2022 medications \n\u2022 herbal therapies \n\u2022 alcohol or recreational drug use \n\u2022 toxin exposure',
                       'Question' : [{'question' : 'Check Does the patient have all of the following findings suggesting acute liver failure?\
                       \n\u2022 acute hepatocellular injury with liver tests typically more than 10 times the upper limit of normal (ULN)\
                       \n\u2022 hepatic encephalopathy\
                       \n\u2022 a prolonged prothrombin time (INR ≥1.5)', 'type' : 'YES NO Q', 'answer': ['YES', 'NO'], 'next step': ['Suggestion', 'Check value']}],
                       'Computation' : None,
                       'Suggestion' : 'Life-saving interventions should not be delayed while awaiting the results of diagnostic testing.\
                       \n\u2022 Provide fluid resuscitation and hemodynamic support.\
                       \n\u2022 Obtain urgent consultation with a clinician who has expertise in acute liver failure.'
                       },
                      {'Name' : 'massive ALT, AST',
                       'Question based' : False,
                       'Value based': True,
                       'Operation' : {'value' : 5000, 'coefficient' : 1, 'operator' : 'greater'},
                       'Obtain' :  '\u2022 Acetaminophen (paracetamol) level, toxicology screen (eg, screen for cocaine, methamphetamine, heroin)\
                       \n\u2022 Acute viral hepatitis serologies, including:\
                       \n  1. Immunoglobulin (Ig) M anti-hepatitis A\
                       \n  2. Hepatitis B surface antigen (HBsAg), IgM anti-hepatitis B core (anti-HBc), antibody toHBsAg\
                       \n  3. Anti-hepatitis C virus antibodies, hepatitis C\
                       \n\u2022 Serum pregnancy test in women not already known to be pregnant\
                       \n\u2022 Markers for autoimmune disease – Antinuclear antibodies, antismooth muscle antibodies, anti-liver/kidney microsomal antibody type 1, Ig levels\
                       \n\u2022 Right upper quadrant ultrasound with Doppler studies of the portal and hepatic veins, hepatic artery',
                       'Question' : None,
                       'Computation' : None,
                       'Suggestion' : 'ischemic or drug induced hepatitis'
                       },
                      {'Name' : 'marked elevation',
                       'Question based' : False,
                       'Value based': True,
                       'Operation' : {'value' : None, 'coefficient' : 15, 'operator' : 'greater'},
                       'Obtain' : '\u2022 Acetaminophen (paracetamol) level, toxicology screen (eg, screen for cocaine, methamphetamine, heroin)\
                       \n\u2022 Acute viral hepatitis serologies, including:\
                       \n  1. Immunoglobulin (Ig) M anti-hepatitis A\
                       \n  2. Hepatitis B surface antigen (HBsAg), IgM anti-hepatitis B core (anti-HBc), antibody toHBsAg\
                       \n  3. Anti-hepatitis C virus antibodies, hepatitis C\
                       \n\u2022 Serum pregnancy test in women not already known to be pregnant\
                       \n\u2022 Markers for autoimmune disease – Antinuclear antibodies, antismooth muscle antibodies, anti-liver/kidney microsomal antibody type 1, Ig levels\
                       \n\u2022 Right upper quadrant ultrasound with Doppler studies of the portal and hepatic veins, hepatic artery',
                       'Question' : None,
                       'Computation' : None,
                       'Suggestion' : None
                       },
                      {'Name' : 'mild to moderate elevation',
                       'Question based' : False,
                       'Value based': True,
                       'Operation' : {'value' : None, 'coefficient1' : 5, 'coefficient2' : 15, 'operator' : 'between'},
                       'Obtain' : 'Screen for chronic alcohol use.\
                       \n\u2022 Serologic tests for chronic hepatitis B and C infection\
                       \n\u2022 Serum iron, total iron binding capacity, ferritin\
                       \n\u2022 Lipid profile\
                       \n\u2022 Glycated hemoglobin (A1C)\
                       \n\u2022 Right upper quadrant ultrasound\
                       \nProvide targeted evaluation and management of any abnormal tests.\
                       \nIf negative initial testing, symptomatic patients require evaluation and testing for less common causes of liver disease and for extrahepatic conditions.',
                       'Question' : None,
                       'Computation' : None,
                       'Suggestion' : ''
                       },
                      {'Name' : 'very mild elevation',
                       'Question based' : False,
                       'Value based': True,
                       'Operation' : {'value' : None, 'coefficient' : 5, 'operator' : 'less'},
                       'Obtain' :None,
                       'Question' : None,
                       'Computation' : None,
                       'Suggestion' : 'recheck the liver tests in three to six months'
                       },
                      
            ],
            'low' : None
        }
    },
    'AST' : {
        'name' : ['AST', 'ASTA', 'ASPARTATE AMINOTRANSFERASE'],
        'multiple factors' : {'type' : True, 'other factors' : 'ALT', 'relation' : 'or'},
        'reference range' : {
            'female' : [{'Name' : 'AST', 'Lower Limit' : 9, 'Upper Limit' : 32 }],
            'male' : [{'Name' : 'AST', 'Lower Limit' : 10, 'Upper Limit' : 40 }]
        },
        'abnormality':{
            'high' : [
                      {'Name' : 'Review',
                       'Question based' : True,
                       'Value based': False,
                       'Operation': None,
                       'Obtain' : 'REVIEW:\n\u2022 Tests that may be available at the time of diagnosis: \
                       \n  1. liver biochemical tests including total and direct bilirubin, alkaline phosphatase, gamma-glutamyl transpeptidase [GGT], albumin;\
                       \n  2. serum electrolytes, blood urea nitrogen [BUN], creatinine, glucose, and other chemistries;\
                       \n  3. complete blood count [CBC] with differential and platelet count;\
                       \n  4. international normalized ratio\
                       \n\u2022 medications \n\u2022 herbal therapies \n\u2022 alcohol or recreational drug use \n\u2022 toxin exposure',
                       'Question' : [{'question' : 'Check Does the patient have all of the following findings suggesting acute liver failure?\
                       \n\u2022 acute hepatocellular injury with liver tests typically more than 10 times the upper limit of normal (ULN)\
                       \n\u2022 hepatic encephalopathy\
                       \n\u2022 a prolonged prothrombin time (INR ≥1.5)', 'type' : 'YES NO Q', 'answer': ['YES', 'NO'], 'next step': ['Suggestion', 'Check value']}],
                       'Computation' : None,
                       'Suggestion' : 'Life-saving interventions should not be delayed while awaiting the results of diagnostic testing.\
                       \n\u2022 Provide fluid resuscitation and hemodynamic support.\
                       \n\u2022 Obtain urgent consultation with a clinician who has expertise in acute liver failure.'
                       },
                      {'Name' : 'massive AST',
                       'Question based' : False,
                       'Value based': True,
                       'Operation' : {'value' : 5000, 'coefficient' : 1, 'operator' : 'greater'},
                       'Obtain' : '\u2022 Acetaminophen (paracetamol) level, toxicology screen (eg, screen for cocaine, methamphetamine, heroin)\
                       \n\u2022 Acute viral hepatitis serologies, including:\
                       \n  1. Immunoglobulin (Ig) M anti-hepatitis A\
                       \n  2. Hepatitis B surface antigen (HBsAg), IgM anti-hepatitis B core (anti-HBc), antibody toHBsAg\
                       \n  3. Anti-hepatitis C virus antibodies, hepatitis C\
                       \n\u2022 Serum pregnancy test in women not already known to be pregnant\
                       \n\u2022 Markers for autoimmune disease – Antinuclear antibodies, antismooth muscle antibodies, anti-liver/kidney microsomal antibody type 1, Ig levels\
                       \n\u2022 Right upper quadrant ultrasound with Doppler studies of the portal and hepatic veins, hepatic artery',
                       'Question' : None,
                       'Computation' : None,
                       'Suggestion' : 'rhabdomyolysis, heat stroke'
                       },
                      {'Name' : 'massive ALT, AST',
                       'Question based' : False,
                       'Value based': True,
                       'Operation' : {'value' : 5000, 'coefficient' : 1, 'operator' : 'greater'},
                       'Obtain' :  '\u2022 Acetaminophen (paracetamol) level, toxicology screen (eg, screen for cocaine, methamphetamine, heroin)\
                       \n\u2022 Acute viral hepatitis serologies, including:\
                       \n  1. Immunoglobulin (Ig) M anti-hepatitis A\
                       \n  2. Hepatitis B surface antigen (HBsAg), IgM anti-hepatitis B core (anti-HBc), antibody toHBsAg\
                       \n  3. Anti-hepatitis C virus antibodies, hepatitis C\
                       \n\u2022 Serum pregnancy test in women not already known to be pregnant\
                       \n\u2022 Markers for autoimmune disease – Antinuclear antibodies, antismooth muscle antibodies, anti-liver/kidney microsomal antibody type 1, Ig levels\
                       \n\u2022 Right upper quadrant ultrasound with Doppler studies of the portal and hepatic veins, hepatic artery',
                       'Question' : None,
                       'Computation' : None,
                       'Suggestion' : 'ischemic or drug induced hepatitis'
                       },
                      {'Name' : 'marked elevation',
                       'Question based' : False,
                       'Value based': True,
                       'Operation' : {'value' : None, 'coefficient' : 15, 'operator' : 'greater'},
                       'Obtain' : '\u2022 Acetaminophen (paracetamol) level, toxicology screen (eg, screen for cocaine, methamphetamine, heroin)\
                       \n\u2022 Acute viral hepatitis serologies, including:\
                       \n  1. Immunoglobulin (Ig) M anti-hepatitis A\
                       \n  2. Hepatitis B surface antigen (HBsAg), IgM anti-hepatitis B core (anti-HBc), antibody toHBsAg\
                       \n  3. Anti-hepatitis C virus antibodies, hepatitis C\
                       \n\u2022 Serum pregnancy test in women not already known to be pregnant\
                       \n\u2022 Markers for autoimmune disease – Antinuclear antibodies, antismooth muscle antibodies, anti-liver/kidney microsomal antibody type 1, Ig levels\
                       \n\u2022 Right upper quadrant ultrasound with Doppler studies of the portal and hepatic veins, hepatic artery',
                       'Question' : None,
                       'Computation' : None,
                       'Suggestion' : None
                       },
                      {'Name' : 'mild to moderate elevation',
                       'Question based' : False,
                       'Value based': True,
                       'Operation' : {'value' : None, 'coefficient1' : 5, 'coefficient2' : 15, 'operator' : 'between'},
                       'Obtain' : 'Screen for chronic alcohol use.\
                       \n\u2022 Serologic tests for chronic hepatitis B and C infection\
                       \n\u2022 Serum iron, total iron binding capacity, ferritin\
                       \n\u2022 Lipid profile\
                       \n\u2022 Glycated hemoglobin (A1C)\
                       \n\u2022 Right upper quadrant ultrasound\
                       \nProvide targeted evaluation and management of any abnormal tests.\
                       \nIf negative initial testing, symptomatic patients require evaluation and testing for less common causes of liver disease and for extrahepatic conditions.',
                       'Question' : None,
                       'Computation' : None,
                       'Suggestion' : ''
                       },
                      {'Name' : 'very mild elevation',
                       'Question based' : False,
                       'Value based': True,
                       'Operation' : {'value' : None, 'coefficient' : 5, 'operator' : 'less'},
                       'Obtain' :None,
                       'Question' : None,
                       'Computation' : None,
                       'Suggestion' : 'recheck the liver tests in three to six months'
                       },
                      
            ],
            'low' : None
        }
    },
    'ALP' : {
        'name' : ['ALP', 'ALKALINE PHOSPHATASE'],
        'multiple factors' : {'type' : False, 'other factors' : None, 'relation' : None},
        'reference range' : {
            'female' : [{'Name' : 'alkaline phosphatase', 'Lower Limit' : 30, 'Upper Limit' : 120 }],
            'male' : [{'Name' : 'alkaline phosphatase', 'Lower Limit' : 30, 'Upper Limit' : 120 }]
        },
        'abnormality':{
            'high' : [ 
                      {'Name' : 'Review',
                       'Question based' : True,
                       'Value based': False,
                       'Operation' : None,
                       'Obtain' :'Check other liver biochemical tests, including alanine aminotransferase (ALT), aspartateaminotransferase (AST), and bilirubin',
                       'Question' :  [{'question' : 'Are other liver biochemical tests abnormal?', 'type' : 'YES NO Q', 'answer': ['YES', 'NO'], 'next step': ['abnormal liver biochemical tests', 'normal liver biochemical tests']}],
                       'Computation' : None,
                       'Suggestion' : None
                       },
                      {'Name' : 'abnormal liver biochemical tests',
                       'Question based' : False,
                       'Value based': False,
                       'Operation' : None,
                       'Obtain' :'Since other liver biochemical tests are abnormal, the elevated alkaline phosphatase suggests liver disease.\
                       \n\u2022 Perform a history and physical examination to identify potential risk factors for liver disease, clues to the etiology, and signs of chronic liver disease.\
                       \n\u2022 Review medications to identify any drugs that may cause acute and chronic cholestasis.\
                       \n\u2022 Perform a right upper quadrant ultrasound to further characterize a cholestatic pattern of abnormal liver biochemical test as extrahepatic or intrahepatic.',
                       'Question' : None,
                       'Computation' : None,
                       'Suggestion' : ['Differential diagnosis of cholestatic jaundice: Extrahepatic\
                       \n\u25AA Cholangiopathies and other disorders involving bile ducts\
                       \n \u2022  Cholelithiasis\
                       \n \u2022  Biliary strictures after invasive procedure\
                       \n \u2022  Cholangiocellular carcinoma\
                       \n \u2022  Primary sclerosing cholangitis\
                       \n \u2022  AIDS cholangiopathy\
                       \n   1. CMV (cytomegalovirus)\
                       \n   2. Cryptosporidium sp\
                       \n   3. HIV (human immunodeficiency virus)\
                       \n \u2022  Choledochal cyst\
                       \n \u2022  Sphincter of Oddi dysfunction\
                       \n \u2022  Parasitic infections\
                       \n      Ascaris lumricoides\
                       \n \u2022  Histiocytosis X\
                       \n\u25AA Extrinsic causes\
                       \n \u2022  Pancreatitis (acute and chronic)\
                       \n \u2022  Pancreatic carcinoma\
                       \n \u2022  Portal adenopathy\
                       \n   1. Metastases\
                       \n   2. Tuberculosis\
                       \n \u2022  Periampullary carcinoma\
                       \n \u2022  Periampullary diverticulum\
                       \n \u2022  Mirizzi\'s syndrome',
                       'Differential diagnosis of cholestatic jaundice: Intrahepatic\
                       \n\u25AA Acute hepatocellular\
                       \n \u2022  Viral hepatitis\
                       \n \u2022  Alcoholic fatty liver and/or hepatitis\
                       \n \u2022  Non-alcoholic steatohepatitis\
                       \n \u2022  Drugs\
                       \n\u25AA Chronic hepatocellular\
                       \n \u2022  Primary sclerosing cholangitis\
                       \n \u2022  Primary biliary cholangitis\
                       \n \u2022  Drugs\
                       \n \u2022  Hepatitis (viral, alcohol, autoimmune)\
                       \n \u2022  Cirrhosis of any cause\
                       \n\u25AA Multifactorial\
                       \n \u2022  Total parental nutrition\
                       \n \u2022  Systemic infection\
                       \n \u2022  Postoperative\
                       \n \u2022  Sickle cell disease/crisis\
                       \n \u2022  Organ transplantation (rejection; graft-versus-host disease; venoocclusive disease)\
                       \n\u25AA Miscellaneous\
                       \n \u2022  Hypotension/hypoxemia/HF\
                       \n \u2022  Budd-Chiari syndrome\
                       \n \u2022  Parasitic infection (Clonorchis sinensis; Fasciolahepatica)\
                       \n\u25AA Inherited/endocrine\
                       \n \u2022  Benign recurrent intrahepatic cholestasis (BRIC)\
                       \n \u2022  Progressive familial intrahepatic cholestasis(PFIC)\
                       \n \u2022  Low phospholipid-associated cholestasis (LPAC)\
                       \n \u2022  Thyrotoxicosis\
                       \n \u2022  Alagille syndrome\
                       \n \u2022  Disorders of carbohydrate, lipid, or bile acidmetabolism\
                       \n \u2022  Caroli\'s disease\
                       \n \u2022  Pregnancy\
                       \n \u2022  Protoporphyria\
                       \n\u25AA Infiltrative/granulomatous\
                       \n \u2022  Amyloidosis\
                       \n \u2022  Lymphoma (Rarely patients with lymphoma may have hyperbilirubinemia (direct) in the absence of tumor involvement of the liver or extrahepatic obstruction.)\
                       \n \u2022  Sarcoidosis\
                       \n \u2022  Tuberculosis']
                       },
                      {'Name' : 'normal liver biochemical tests',
                       'Question based' : True,
                       'Value based': False,
                       'Operation' : None,
                       'Obtain' :'\n\u2022 Repeat alkaline phosphatase\
                       \n\u2022 Gamma-glutamyl transpeptidase (GGT) or 5\'nucleotidase (5\'-NT)',
                       'Question' : [{'question' : 'Elevated alkaline phosphatase confirmed', 'type' : 'YES NO Q', 'answer': ['YES', 'NO'], 'next step': ['next q', 'nnnnnn']},
                        {'question' : 'Is the GGT or 5\'NT elevated?', 'type' : 'YES NO Q', 'answer': ['YES', 'NO'], 'next step': ['GGT or 5NT elevated', 'GGT or 5NT normal']}],
                       'Computation' : None,
                       'Suggestion' : 'recheck the liver tests in three to six months'
                       },
                      {'Name' : 'GGT or 5NT elevated',
                       'Question based' : False,
                       'Value based': False,
                       'Operation' : None,
                       'Obtain' :None,
                       'Question' : None,
                       'Computation' : None,
                       'Suggestion' : 'The elevated alkaline phosphatase suggests liver disease.'
                       },
                      {'Name' : 'GGT or 5NT normal',
                       'Question based' : False,
                       'Value based': False,
                       'Operation' : None,
                       'Obtain' : 'The elevated alkaline phosphatase suggests bone disease.\
                       Review tests usually available at the time of diagnosis (electrolytes, blood urea nitrogen [BUN], creatinine, calcium). Additional testing may include measurement of the following levels:\
                       \n\u2022 Bone-specific alkaline phosphatase in selected patients (eg, chronic kidney disease, Paget disease)\
                       \n\u2022 Serum calcium, phosphorus, parathyroid hormone, 25-hydroxyvitamin D\
                       \n\u2022 Thyroid-stimulating hormone (TSH)',
                       'Question' : None,
                       'Computation' : None,
                       'Suggestion' : 'An elevated bone alkaline phosphatase may be caused by several disorders including:\
                       \n\u2022 Healing fractures\
                       \n\u2022 Paget disease of bone\
                       \n\u2022 Osteomalacia\
                       \n\u2022 Osteogenic sarcoma, bone metastasis\
                       \n\u2022 Hyperparathyroidism\
                       \n\u2022 Hyperthyroidism'
                       },
            ],
            'low' : None
        }
    }
}




with open('factors.json', 'w') as outfile:
   json.dump(factors, outfile, indent=4, separators=(',', ':'))
